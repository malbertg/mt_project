# %% [markdown]
# **Marina Albert, Ramón Carreño, Charlotte Puopolo**

# %% [markdown]
# # Machine Translation Project
# How may a (target) language change over time if we use MT persistently? Compare
# (automatically) the MT output and the original translation of a (large) set of texts to check
# if there are any words and/or structures that get used less/more frequently.

# %% [markdown]
# ## Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Remember to set the right paths if you want to rerun inference using corpora files.

# %%
# !pip install tqdm
# !pip install sentencepiece
# !pip install transformers
# !pip install sacremoses
# !pip install scattertext
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.4)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.40.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Collecting sacremoses
#   Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacremoses) (2023.12.25)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses) (1.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sacremoses) (4.66.4)
# Installing collected packages: sacremoses
# Successfully installed sacremoses-0.1.1
# Collecting scattertext
#   Downloading scattertext-0.1.19-py3-none-any.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from scattertext) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from scattertext) (1.11.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from scattertext) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from scattertext) (2.0.3)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from scattertext) (0.14.2)
# Collecting flashtext (from scattertext)
#   Downloading flashtext-2.7.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gensim>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from scattertext) (4.3.2)
# Requirement already satisfied: spacy>=3.2 in /usr/local/lib/python3.10/dist-packages (from scattertext) (3.7.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from scattertext) (4.66.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim>=4.0.0->scattertext) (6.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.2->scattertext) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.2->scattertext) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.2->scattertext) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.2->scattertext) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.2->scattertext) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.2->scattertext) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.2->scattertext) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.2->scattertext) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.2->scattertext) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.2->scattertext) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.2->scattertext) (0.9.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.2->scattertext) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.2->scattertext) (2.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.2->scattertext) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy>=3.2->scattertext) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.2->scattertext) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.2->scattertext) (3.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->scattertext) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->scattertext) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->scattertext) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->scattertext) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->scattertext) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels->scattertext) (0.5.6)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy>=3.2->scattertext) (1.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels->scattertext) (1.16.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.2->scattertext) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.2->scattertext) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.2->scattertext) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2->scattertext) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2->scattertext) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2->scattertext) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2->scattertext) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=3.2->scattertext) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=3.2->scattertext) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy>=3.2->scattertext) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy>=3.2->scattertext) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy>=3.2->scattertext) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=3.2->scattertext) (1.1.1)
# Building wheels for collected packages: flashtext
#   Building wheel for flashtext (setup.py) ... done
#   Created wheel for flashtext: filename=flashtext-2.7-py2.py3-none-any.whl size=9296 sha256=46540f036e3c02f9e6397e176d97dd8297cfae5d8dd7c897832e86572ef3d7e5
#   Stored in directory: /root/.cache/pip/wheels/bc/be/39/c37ad168eb2ff644c9685f52554440372129450f0b8ed203dd
# Successfully built flashtext
# Installing collected packages: flashtext, scattertext
# Successfully installed flashtext-2.7 scattertext-0.1.19

# %%
import pandas as pd
from tqdm import tqdm
from transformers import pipeline

# %% [markdown]
# ## Translations

# %%
# Read write operations
def read_corpus(filepath):
    examples = []
    with open(filepath, 'r') as file:
        lines = file.readlines()
        for line in lines:
            examples.append(line.strip())
    return examples


def write_translations(filepath, translations):
    with open(filepath, "w", encoding="utf-8") as file:
        for sentence in translations:
            file.write(sentence + "\n")

# %%
path_to_english_file = 'corpora/esxnli-all-en.csv'
path_to_spanish_file = 'corpora/esxnli-all-es.csv'

en_corpus = read_corpus(path_to_english_file)
es_corpus = read_corpus(path_to_spanish_file)

# %%
# Don't rerun (30 min or +)
es_en_model = 'Helsinki-NLP/opus-mt-es-en'
translator = pipeline(task="translation", model=es_en_model)
#translation = translator(es_corpus[0:5])

# Iterate through each sentence in es_corpus and translate
tr_en_texts = []
#for sentence in tqdm(es_corpus[0:1000]):
for sentence in tqdm(es_corpus):
    translation = translator(sentence)
    tr_en_texts.append(translation)
# Out:
# 100%|██████████| 3320/3320 [58:34<00:00,  1.06s/it]

# %%
translations = [text[0]["translation_text"] for text in tr_en_texts]
print(translations[0])
#write_translations("translations_esxnli_1000_es_en.txt", translations)
write_translations("translations_esxnli_all_es_en.txt", translations)
# Out:
# Let's see if we all have to go on strike until we collect whatever we want.

# %% [markdown]
# ## Creation of a comparison file

# %%
#spanish = es_corpus[:1000]
spanish = es_corpus

# %%
#english = en_corpus[:1000]
english = en_corpus
# Out:
# sentence2,

# %%
# readjusting to remove this one extra line in English
print(english[830])
english.pop(830)
# Out:
# 'sentence2,'

# %%
translations = read_corpus("translations_esxnli_all_es_en.txt")

# %%
comparison_df = pd.DataFrame({'spanish' : spanish,
                                'english_human' : english,
                                'english_mt' : translations },
                                columns=['spanish','english_human', 'english_mt'])

# %%
comparison_df
# Out:
#                                                 spanish  \
# 0     A ver si nos tenemos que poner todos en huelga...
# 1     "Profesor de FP y funcionario de carrera de la...
# 2     "Dos horas después estaba controlado, pero tod...
# 3     Estos que se hacen llamar periodistas se creen...
# 4     "Por eso, un buen día, explota, y a lomos de s...
# ...                                                 ...
# 3315  Cynthia ha mantenido una relación sentimental ...
# 3316  Cynthia no tiene ningún abogado que la represe...
# 3317  Al-Fayed y Eva Mendes son los propietarios de ...
# 3318  Al-Fayed firmó a Eva Mendes imágenes de la cam...
# 3319  Al-Fayed acompañó a Eva Mendes cuando estaba f...
#
#                                           english_human  \
# 0     Maybe we will all have to go on strike until w...
# 1     "He is a professor of Vocational Training and ...
# 2     "Two hours later it was under control, but the...
# 3     "They call themselves journalists and they bel...
# 4     "Therefore, one day he explodes, and on the ba...
# ...                                                 ...
# 3315  Cynthia has maintained a sentimental relations...
# 3316  Cynthia does not have a lawyer to represent her.,
# 3317  Al-Fayed and Eva Mendes own the department sto...
# 3318  Al-Fayed signed pictures of the campaign for E...
# 3319  Al-Fayed accompanied Eva Mendes when she was s...
#
#                                              english_mt
# 0     Let's see if we all have to go on strike until...
# 1     "Professor of FP and career officer of the Dep...
# 2     "Two hours later it was controlled, but the ca...
# 3     Those who call themselves journalists think th...
# 4     "That's why one good day, it explodes, and on ...
# ...                                                 ...
# 3315  Cynthia has had a sentimental relationship wit...
# 3316    Cynthia doesn't have a lawyer to represent her.
# 3317  Al-Fayed and Eva Mendes are the owners of the ...
# 3318  Al-Fayed signed Eva Mendes images of the campa...
# 3319  Al-Fayed accompanied Eva Mendes when she was s...
#
# [3320 rows x 3 columns]

# %%
comparison_df.to_csv('comparison-all-esxnli.csv', index=True)

# %% [markdown]
# ## Automatic analysis

# %% [markdown]
# ### Comparison of unigrams (words)

# %%
from collections import Counter
import nltk
from nltk import word_tokenize

nltk.download('punkt')


# Tokenize function
def tokenize(text):
    return word_tokenize(text.lower())

# Function to count word frequencies
def count_word_frequencies(texts):
    all_words = []
    for text in texts:
        tokens = tokenize(text)
        all_words.extend(tokens)
    return Counter(all_words)

# Calculate word frequencies for human translations
human_word_freq = count_word_frequencies(comparison_df['english_human'])

# Calculate word frequencies for machine translations
mt_word_freq = count_word_frequencies(comparison_df['english_mt'])

# Compare word frequencies
common_words = set(human_word_freq.keys()) & set(mt_word_freq.keys())

# Identify significant differences in word frequencies
differences = {}
for word in common_words:
    human_freq = human_word_freq[word]
    mt_freq = mt_word_freq[word]
    if human_freq != mt_freq:
        differences[word] = (human_freq, mt_freq)

# Set the threshold for significant frequency difference
threshold = 20

# Output the significant differences
print("Significant differences in word frequencies by count:")
for word, (human_freq, mt_freq) in differences.items():
    if abs(human_freq - mt_freq) >= threshold:
        print(f"Word: {word}, Human Frequency: {human_freq}, MT Frequency: {mt_freq}")

# Calculate the total number of instances
total_instances = sum([max(human_freq, mt_freq) for _, (human_freq, mt_freq) in differences.items()])

# Define the percentage threshold
percentage_threshold = 0.0005  # adjust as needed

print("\nSignificant differences in word frequencies by percentage:")
for word, (human_freq, mt_freq) in differences.items():
    # Calculate the threshold based on the percentage
    threshold_p = percentage_threshold * total_instances
    if abs(human_freq - mt_freq) >= threshold_p:
        print(f"Word: {word}, Human Frequency: {human_freq}, MT Frequency: {mt_freq}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Significant differences in word frequencies by count:
# Word: been, Human Frequency: 81, MT Frequency: 133
# Word: this, Human Frequency: 179, MT Frequency: 159
# Word: don, Human Frequency: 38, MT Frequency: 2
# Word: n't, Human Frequency: 83, MT Frequency: 218
# Word: ., Human Frequency: 848, MT Frequency: 2375
# Word: 're, Human Frequency: 10, MT Frequency: 42
# Word: to, Human Frequency: 1100, MT Frequency: 1155
# Word: during, Human Frequency: 42, MT Frequency: 20
# Word: they, Human Frequency: 206, MT Frequency: 157
# Word: s, Human Frequency: 104, MT Frequency: 2
# Word: an, Human Frequency: 139, MT Frequency: 118
# Word: will, Human Frequency: 313, MT Frequency: 271
# Word: ', Human Frequency: 23, MT Frequency: 45
# Word: from, Human Frequency: 165, MT Frequency: 144
# Word: the, Human Frequency: 3376, MT Frequency: 3557
# Word: is, Human Frequency: 895, MT Frequency: 803
# Word: ``, Human Frequency: 1733, MT Frequency: 814
# Word: 's, Human Frequency: 154, MT Frequency: 349
# Word: has, Human Frequency: 264, MT Frequency: 343
# Word: a, Human Frequency: 894, MT Frequency: 865
# Word: ’, Human Frequency: 244, MT Frequency: 1
# Word: of, Human Frequency: 1353, MT Frequency: 1530
# Word: at, Human Frequency: 162, MT Frequency: 140
# Word: for, Human Frequency: 340, MT Frequency: 302
# Word: their, Human Frequency: 142, MT Frequency: 113
# Word: was, Human Frequency: 254, MT Frequency: 208
# Word: do, Human Frequency: 90, MT Frequency: 136
# Word: and, Human Frequency: 793, MT Frequency: 824
# Word: you, Human Frequency: 182, MT Frequency: 213
# Word: year, Human Frequency: 44, MT Frequency: 64
# Word: not, Human Frequency: 399, MT Frequency: 328
# Word: more, Human Frequency: 146, MT Frequency: 169
# Word: '', Human Frequency: 325, MT Frequency: 807
# Word: ,, Human Frequency: 4728, MT Frequency: 2227
# Word: 'm, Human Frequency: 13, MT Frequency: 38
# Word: are, Human Frequency: 429, MT Frequency: 358
# Word: 've, Human Frequency: 4, MT Frequency: 31
#
# Significant differences in word frequencies by percentage:
# Word: been, Human Frequency: 81, MT Frequency: 133
# Word: don, Human Frequency: 38, MT Frequency: 2
# Word: n't, Human Frequency: 83, MT Frequency: 218
# Word: ., Human Frequency: 848, MT Frequency: 2375
# Word: 're, Human Frequency: 10, MT Frequency: 42
# Word: to, Human Frequency: 1100, MT Frequency: 1155
# Word: they, Human Frequency: 206, MT Frequency: 157
# Word: s, Human Frequency: 104, MT Frequency: 2
# Word: will, Human Frequency: 313, MT Frequency: 271
# Word: the, Human Frequency: 3376, MT Frequency: 3557
# Word: is, Human Frequency: 895, MT Frequency: 803
# Word: ``, Human Frequency: 1733, MT Frequency: 814
# Word: 's, Human Frequency: 154, MT Frequency: 349
# Word: has, Human Frequency: 264, MT Frequency: 343
# Word: a, Human Frequency: 894, MT Frequency: 865
# Word: ’, Human Frequency: 244, MT Frequency: 1
# Word: of, Human Frequency: 1353, MT Frequency: 1530
# Word: for, Human Frequency: 340, MT Frequency: 302
# Word: their, Human Frequency: 142, MT Frequency: 113
# Word: was, Human Frequency: 254, MT Frequency: 208
# Word: do, Human Frequency: 90, MT Frequency: 136
# Word: and, Human Frequency: 793, MT Frequency: 824
# Word: you, Human Frequency: 182, MT Frequency: 213
# Word: not, Human Frequency: 399, MT Frequency: 328
# Word: '', Human Frequency: 325, MT Frequency: 807
# Word: ,, Human Frequency: 4728, MT Frequency: 2227
# Word: 'm, Human Frequency: 13, MT Frequency: 38
# Word: are, Human Frequency: 429, MT Frequency: 358
# Word: 've, Human Frequency: 4, MT Frequency: 31

# %% [markdown]
# ### Estimating lexical richness: Perplexity & Type-Token Ratio

# %%
import numpy as np
from collections import Counter

def calculate_unigram_probabilities(texts):
    # Count the frequency of each word
    word_freq = count_word_frequencies(texts)

    # Calculate unigram model probabilities
    total_words = sum(word_freq.values())  # total number of words in corpus
    probs = {word: count / total_words for word, count in word_freq.items()}

    return probs

def perplexity(probs):
    log_probabilities = np.log2(probs)
    entropy = -np.mean(log_probabilities)
    perplexity = 2 ** entropy
    return perplexity

def ttr(texts):  # type-token ratio
    # Obtain all corpus words
    words = []
    for text in texts:
        tokens = tokenize(text)
        words.extend(tokens)

    # Count the number of unique words (types)
    unique_words = set(words)
    num_unique_words = len(unique_words)

    # Count the total number of words (tokens)
    num_tokens = len(words)

    # Calculate the TTR
    ttr = num_unique_words / num_tokens

    return ttr

# Calculate probabilities
human_probs = calculate_unigram_probabilities(comparison_df['english_human'])
mt_probs = calculate_unigram_probabilities(comparison_df['english_mt'])

# Calculate perplexities
human_perp = perplexity(list(human_probs.values()))
mt_perp = perplexity(list(mt_probs.values()))

# Calculate TTRs
human_ttr = ttr(comparison_df['english_human'])
mt_ttr = ttr(comparison_df['english_mt'])

# Comparison time!
print(f"Human texts PERPLEXITY: {human_perp} | MT texts PERPLEXITY: {mt_perp}")  # does this make any sense? what is our baseline?
print(f"Human texts TTR: {human_ttr} | MT texts TTR: {mt_ttr}")  # 11.7% vs 11.4% - significant?
# Out:
# Human texts PERPLEXITY: 25220.061396570567 | MT texts PERPLEXITY: 21416.966481893287
# Human texts TTR: 0.15371484150141923 | MT texts TTR: 0.13619065443882963

# %% [markdown]
# ### Comparison of bigrams

# %%
from nltk import bigrams
from collections import Counter
from nltk.tokenize import word_tokenize
import string
from nltk.corpus import stopwords
import nltk

nltk.download('punkt')
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))


# Function to count bigram frequencies, excluding stopwords and punctuation
def count_bigram_frequencies_clean(texts):
    all_bigrams = []
    for text in texts:
        tokens = word_tokenize(text)
        tokens = [token.lower() for token in tokens if token.lower() not in stop_words and not all(char in string.punctuation for char in token)]
     #   tokens = [token.lower() for token in tokens if token.lower() not in stop_words and token.lower() not in string.punctuation]
     #   tokens = [token for token in tokenize(text) if token not in stop_words and token not in punctuation]
        bigrams_list = list(bigrams(tokens))
        all_bigrams.extend(bigrams_list)
    return Counter(all_bigrams)

# Calculate bigram frequencies for human translations (excluding stopwords and punctuation)
human_bigram_freq_clean = count_bigram_frequencies_clean(comparison_df['english_human'])

# Calculate bigram frequencies for machine translations (excluding stopwords and punctuation)
mt_bigram_freq_clean = count_bigram_frequencies_clean(comparison_df['english_mt'])

# Get the top 50 bigrams for human translations
top_50_human_bigrams_clean = human_bigram_freq_clean.most_common(50)

# Get the top 50 bigrams for machine translations
top_50_mt_bigrams_clean = mt_bigram_freq_clean.most_common(50)

# Output the top 50 bigrams for human translations
print("Top 50 meaningful bigrams for human translations:")
for bigram, freq in top_50_human_bigrams_clean:
    print(f"Bigram: {bigram}, Frequency: {freq}")

# Output the top 50 bigrams for machine translations
print("\nTop 50 meaningful bigrams for machine translations:")
for bigram, freq in top_50_mt_bigrams_clean:
    print(f"Bigram: {bigram}, Frequency: {freq}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Top 50 meaningful bigrams for human translations:
# Bigram: ('”', '“'), Frequency: 12
# Bigram: ('ca', "n't"), Frequency: 10
# Bigram: ('real', 'estate'), Frequency: 10
# Bigram: ('company', "'s"), Frequency: 8
# Bigram: ('michael', 'jackson'), Frequency: 8
# Bigram: ('world', 'cup'), Frequency: 8
# Bigram: ('city', 'council'), Frequency: 7
# Bigram: ('united', 'states'), Frequency: 7
# Bigram: ('three', 'months'), Frequency: 7
# Bigram: ('long', 'time'), Frequency: 7
# Bigram: ('de', 'azúa'), Frequency: 7
# Bigram: ('years', 'old'), Frequency: 6
# Bigram: ('young', 'people'), Frequency: 6
# Bigram: ('wo', "n't"), Frequency: 6
# Bigram: ('children', "'s"), Frequency: 6
# Bigram: ('last', 'year'), Frequency: 6
# Bigram: ('million', 'people'), Frequency: 6
# Bigram: ('fair', 'trade'), Frequency: 6
# Bigram: ('’', 'know'), Frequency: 6
# Bigram: ('louis', 'vuitton'), Frequency: 6
# Bigram: ('last', 'year.'), Frequency: 6
# Bigram: ('real', 'madrid'), Frequency: 5
# Bigram: ('basque', 'country'), Frequency: 5
# Bigram: ('would', 'like'), Frequency: 5
# Bigram: ('agricultural', 'production'), Frequency: 5
# Bigram: ('time', 'ago'), Frequency: 5
# Bigram: ('olympic', 'games'), Frequency: 5
# Bigram: ('take', 'care'), Frequency: 5
# Bigram: ('family', 'support'), Frequency: 5
# Bigram: ('one', 'day'), Frequency: 4
# Bigram: ('agreed', 'upon'), Frequency: 4
# Bigram: ('paco', 'león'), Frequency: 4
# Bigram: ('iberian', 'pigs'), Frequency: 4
# Bigram: ('food', 'industry'), Frequency: 4
# Bigram: ('sheryl', 'crow'), Frequency: 4
# Bigram: ('make', 'us'), Frequency: 4
# Bigram: ('increase', 'agricultural'), Frequency: 4
# Bigram: ('sexual', 'identity'), Frequency: 4
# Bigram: ('condoleeza', 'rice'), Frequency: 4
# Bigram: ('rice', 'mahmud'), Frequency: 4
# Bigram: ('bruce', 'willis'), Frequency: 4
# Bigram: ('get', 'rid'), Frequency: 4
# Bigram: ('madrid', 'catalonia'), Frequency: 4
# Bigram: ('new', 'york'), Frequency: 4
# Bigram: ('elizabeth', 'ii'), Frequency: 4
# Bigram: ('almost', 'half'), Frequency: 4
# Bigram: ('historical', 'conditions'), Frequency: 4
# Bigram: ('’', '’'), Frequency: 4
# Bigram: ("n't", 'think'), Frequency: 4
# Bigram: ('home', 'delivery'), Frequency: 4
#
# Top 50 meaningful bigrams for machine translations:
# Bigram: ('ca', "n't"), Frequency: 28
# Bigram: ('wo', "n't"), Frequency: 12
# Bigram: ('last', 'year'), Frequency: 10
# Bigram: ('three', 'months'), Frequency: 9
# Bigram: ('real', 'estate'), Frequency: 9
# Bigram: ('world', 'cup'), Frequency: 9
# Bigram: ('young', 'people'), Frequency: 9
# Bigram: ("n't", 'know'), Frequency: 9
# Bigram: ("n't", 'want'), Frequency: 8
# Bigram: ('united', 'states'), Frequency: 7
# Bigram: ('people', "n't"), Frequency: 7
# Bigram: ("n't", 'make'), Frequency: 7
# Bigram: ('olympic', 'games'), Frequency: 7
# Bigram: ('gon', 'na'), Frequency: 7
# Bigram: ('louis', 'vuitton'), Frequency: 7
# Bigram: ('let', "'s"), Frequency: 6
# Bigram: ('city', 'council'), Frequency: 6
# Bigram: ('basque', 'country'), Frequency: 6
# Bigram: ('would', 'like'), Frequency: 6
# Bigram: ('michael', 'jackson'), Frequency: 6
# Bigram: ('long', 'time'), Frequency: 6
# Bigram: ('today', "'s"), Frequency: 6
# Bigram: ("n't", 'like'), Frequency: 6
# Bigram: ('fair', 'trade'), Frequency: 6
# Bigram: ('de', 'azúa'), Frequency: 6
# Bigram: ('per', 'cent'), Frequency: 5
# Bigram: ('government', "'s"), Frequency: 5
# Bigram: ('years', 'old'), Frequency: 5
# Bigram: ('agricultural', 'production'), Frequency: 5
# Bigram: ('previous', 'year'), Frequency: 5
# Bigram: ('real', 'madrid'), Frequency: 5
# Bigram: ("'re", 'going'), Frequency: 5
# Bigram: ('economic', 'crisis'), Frequency: 5
# Bigram: ('several', 'times'), Frequency: 5
# Bigram: ("n't", 'go'), Frequency: 5
# Bigram: ("n't", 'feel'), Frequency: 5
# Bigram: ('company', "'s"), Frequency: 5
# Bigram: ('crisis', 'management'), Frequency: 5
# Bigram: ('science', 'fiction'), Frequency: 5
# Bigram: ('new', 'york'), Frequency: 5
# Bigram: ('women', 'men'), Frequency: 5
# Bigram: ("n't", 'get'), Frequency: 5
# Bigram: ('lot', 'money'), Frequency: 5
# Bigram: ('less', 'less'), Frequency: 5
# Bigram: ("n't", 'work'), Frequency: 5
# Bigram: ('years', 'ago'), Frequency: 5
# Bigram: ('iberian', 'pigs'), Frequency: 4
# Bigram: ('renowned', 'architects'), Frequency: 4
# Bigram: ('food', 'industry'), Frequency: 4
# Bigram: ('sheryl', 'crow'), Frequency: 4

# %% [markdown]
# ### Comparison of trigrams

# %%
from nltk import trigrams

# Function to count trigram frequencies, excluding stopwords and punctuation
def count_trigram_frequencies_clean(texts):
    all_trigrams = []
    for text in texts:
        tokens = word_tokenize(text)
        tokens = [token.lower() for token in tokens if token.lower() not in stop_words and not all(char in string.punctuation for char in token)]
     #   tokens = [token for token in tokenize(text) if token not in stop_words and token not in punctuation]
        trigrams_list = list(trigrams(tokens))
        all_trigrams.extend(trigrams_list)
    return Counter(all_trigrams)

# Calculate trigram frequencies for human translations (excluding stopwords and punctuation)
human_trigram_freq_clean = count_trigram_frequencies_clean(comparison_df['english_human'])

# Calculate trigram frequencies for machine translations (excluding stopwords and punctuation)
mt_trigram_freq_clean = count_trigram_frequencies_clean(comparison_df['english_mt'])

# Get the top 50 trigrams for human translations
top_50_human_trigrams_clean = human_trigram_freq_clean.most_common(50)

# Get the top 50 trigrams for machine translations
top_50_mt_trigrams_clean = mt_trigram_freq_clean.most_common(50)

# Output the top 50 trigrams for human translations
print("Top 50 meaningful trigrams for human translations:")
for trigram, freq in top_50_human_trigrams_clean:
    print(f"Trigram: {trigram}, Frequency: {freq}")

# Output the top 50 trigrams for machine translations
print("\nTop 50 meaningful trigrams for machine translations:")
for trigram, freq in top_50_mt_trigrams_clean:
    print(f"Trigram: {trigram}, Frequency: {freq}")
# Out:
# Top 50 meaningful trigrams for human translations:
# Trigram: ('increase', 'agricultural', 'production'), Frequency: 4
# Trigram: ('condoleeza', 'rice', 'mahmud'), Frequency: 4
# Trigram: ('long', 'time', 'ago'), Frequency: 4
# Trigram: ('real', 'estate', 'market'), Frequency: 4
# Trigram: ('“', 'gladiator', '”'), Frequency: 4
# Trigram: ('eighty', 'desirable', 'men'), Frequency: 4
# Trigram: ('john', 'edward', 'thomas'), Frequency: 4
# Trigram: ('33', 'chilean', 'miners'), Frequency: 4
# Trigram: ('rock', 'band', 'aerosmith'), Frequency: 4
# Trigram: ('finnish', 'computer', 'engineer'), Frequency: 3
# Trigram: ('consumer', 'protection', 'improvement'), Frequency: 3
# Trigram: ('contained', 'small', 'capsules'), Frequency: 3
# Trigram: ('agricultural', 'production', 'developing'), Frequency: 3
# Trigram: ('sexual', 'identity', 'law'), Frequency: 3
# Trigram: ('rice', 'mahmud', 'abas'), Frequency: 3
# Trigram: ('homosexual', 'couples', 'rights'), Frequency: 3
# Trigram: ('couples', 'rights', 'heterosexual'), Frequency: 3
# Trigram: ('queen', 'elizabeth', 'ii'), Frequency: 3
# Trigram: ('billy', 'bought', 'donkey'), Frequency: 3
# Trigram: ('offering', 'accepting', 'sexual'), Frequency: 3
# Trigram: ('accepting', 'sexual', 'services'), Frequency: 3
# Trigram: ('sexual', 'services', 'public'), Frequency: 3
# Trigram: ('interests', 'producers', 'consumers'), Frequency: 3
# Trigram: ('fight', 'aids', 'malaria'), Frequency: 3
# Trigram: ('increase', 'fat', 'content'), Frequency: 3
# Trigram: ('doctor', 'miguel', 'aizpún'), Frequency: 3
# Trigram: ('red', 'blood', 'cells'), Frequency: 3
# Trigram: ('climate', 'insecurity', 'general'), Frequency: 3
# Trigram: ('insecurity', 'general', 'economic'), Frequency: 3
# Trigram: ('general', 'economic', 'mistrust'), Frequency: 3
# Trigram: ('antena', '3', 'televisión'), Frequency: 3
# Trigram: ('3', 'televisión', 'española'), Frequency: 3
# Trigram: ('televisión', 'española', 'tve'), Frequency: 3
# Trigram: ('offer', 'fixed', 'interest'), Frequency: 3
# Trigram: ('first', 'active', 'immunization'), Frequency: 3
# Trigram: ('resolution', 'notification', 'procedure'), Frequency: 3
# Trigram: ('banco', 'espirito', 'santo'), Frequency: 3
# Trigram: ('access', 'voice', 'data'), Frequency: 3
# Trigram: ('100', 'refund', 'ticket'), Frequency: 3
# Trigram: ('first', 'quarter', '2004'), Frequency: 3
# Trigram: ('expression', 'language', 'instinct'), Frequency: 3
# Trigram: ('territory', 'specific', 'culture'), Frequency: 3
# Trigram: ('“', 'fortuny', 'gypsy'), Frequency: 3
# Trigram: ('fortuny', 'gypsy', '”'), Frequency: 3
# Trigram: ('election', 'promises', 'made'), Frequency: 3
# Trigram: ('ortega', "'s", 'project'), Frequency: 3
# Trigram: ('drawing', 'chocolate', 'using'), Frequency: 3
# Trigram: ('streets', 'beverly', 'hills'), Frequency: 3
# Trigram: ('president', 'islamic', 'republic'), Frequency: 3
# Trigram: ('islamic', 'republic', 'mauritania'), Frequency: 3
#
# Top 50 meaningful trigrams for machine translations:
# Trigram: ('condoleeza', 'rice', 'mahmud'), Frequency: 4
# Trigram: ('concrete', 'historical', 'conditions'), Frequency: 4
# Trigram: ('historical', 'conditions', 'today'), Frequency: 4
# Trigram: ('conditions', 'today', "'s"), Frequency: 4
# Trigram: ('today', "'s", 'world'), Frequency: 4
# Trigram: ('declare', 'suspension', 'payments'), Frequency: 4
# Trigram: ('young', 'people', "n't"), Frequency: 4
# Trigram: ('trip', 'cartagena', 'de'), Frequency: 4
# Trigram: ('cartagena', 'de', 'indias'), Frequency: 4
# Trigram: ('de', 'indias', 'colombia'), Frequency: 4
# Trigram: ('producers', 'consumers', 'owners'), Frequency: 4
# Trigram: ('consumers', 'owners', 'capital'), Frequency: 4
# Trigram: ('dr.', 'miguel', 'aizpún'), Frequency: 4
# Trigram: ('climate', 'insecurity', 'general'), Frequency: 4
# Trigram: ('insecurity', 'general', 'economic'), Frequency: 4
# Trigram: ('general', 'economic', 'mistrust'), Frequency: 4
# Trigram: ('offer', 'fixed', 'interest'), Frequency: 4
# Trigram: ('inclusion', 'persons', 'disabilities'), Frequency: 4
# Trigram: ('persons', 'disabilities', 'spaces'), Frequency: 4
# Trigram: ('disabilities', 'spaces', 'general'), Frequency: 4
# Trigram: ('spaces', 'general', 'population'), Frequency: 4
# Trigram: ('banco', 'espirito', 'santo'), Frequency: 4
# Trigram: ('certificate', 'last', 'wills'), Frequency: 4
# Trigram: ('kenya', 'burkina', 'faso'), Frequency: 4
# Trigram: ('hans', 'ulrich', 'franck'), Frequency: 4
# Trigram: ('anguita', "'s", 'speech'), Frequency: 4
# Trigram: ('given', 'territory', 'specific'), Frequency: 4
# Trigram: ('territory', 'specific', 'culture'), Frequency: 4
# Trigram: ('cross', 'order', 'civil'), Frequency: 4
# Trigram: ('john', 'edward', 'thomas'), Frequency: 4
# Trigram: ('33', 'chilean', 'miners'), Frequency: 4
# Trigram: ('city', 'council', 'capital'), Frequency: 3
# Trigram: ('finnish', 'computer', 'engineer'), Frequency: 3
# Trigram: ("'the", 'boarding', 'school'), Frequency: 3
# Trigram: ('series', 'dragon', 'ball'), Frequency: 3
# Trigram: ('contained', 'small', 'capsules'), Frequency: 3
# Trigram: ('buy', 'city', "'s"), Frequency: 3
# Trigram: ('city', "'s", 'great'), Frequency: 3
# Trigram: ("'s", 'great', 'restorers'), Frequency: 3
# Trigram: ('go', 'back', 'brazil'), Frequency: 3
# Trigram: ('agricultural', 'production', 'developing'), Frequency: 3
# Trigram: ('production', 'developing', 'countries'), Frequency: 3
# Trigram: ('sexual', 'identity', 'law'), Frequency: 3
# Trigram: ('decree', 'single', 'health'), Frequency: 3
# Trigram: ('single', 'health', 'area'), Frequency: 3
# Trigram: ('wireless', 'service', 'providers'), Frequency: 3
# Trigram: ('supreme', 'court', 'state'), Frequency: 3
# Trigram: ('court', 'state', 'new'), Frequency: 3
# Trigram: ('state', 'new', 'jersey'), Frequency: 3
# Trigram: ('new', 'jersey', 'usa'), Frequency: 3

# %% [markdown]
# ## Creation of comparison file for manual linguistic analysis

# %%
import pandas as pd

# Load the original DataFrame
comparison_df = pd.read_csv('comparison-all-esxnli.csv')

# Create a new DataFrame for the two corpora with a category column
corpus_df = pd.concat([comparison_df[['spanish', 'english_human']].rename(columns={'english_human': 'text'}),
                       comparison_df[['spanish', 'english_mt']].rename(columns={'english_mt': 'text'})],
                      ignore_index=True)

# Add a category column indicating human or machine translation
corpus_df['category'] = ['human-translation'] * len(comparison_df) + ['machine-translation'] * len(comparison_df)

# Save the new DataFrame to a CSV file
corpus_df.to_csv('corpus_with_category.csv', index=False)

# %% [markdown]
# ## Scattertext

# %%
import pandas as pd
import scattertext as st

corpus_df = pd.read_csv('corpus_with_category.csv')

# creating a Scattertext Corpus
corpus = st.CorpusFromPandas(corpus_df,
                              category_col='category',
                              text_col='text',
                              nlp=st.whitespace_nlp_with_sentences
                             ).build()

# generate the HTML visualization
html = st.produce_scattertext_explorer(corpus,
                                       category='human-translation',
                                       category_name='Human Translation',
                                       not_category_name='Machine Translation',
                                       width_in_pixels=1000,
                                       metadata=corpus_df['spanish'])

# Save the HTML file
with open('mt-scattertext_visualization-1.html', 'w') as f:
    f.write(html)
